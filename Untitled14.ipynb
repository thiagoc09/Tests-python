# %%
def convert_columns_types(df):
    # Preenche com 0 os campos INT e FLOAT
    # Converte os tipos das colunas

    df['cod_pi'].fillna(0,inplace=True)
    df['cod_pi'] = df['actions'].astype(int)
    df['cod_ap'].fillna(0,inplace=True)
    df['cod_ap'] = df['cod_ap'].astype(int)
    df['cod_plano'].fillna(0,inplace=True)
    df['cod_plano'] = df['cod_plano'].astype(int)
    df['cod_po'].fillna(0,inplace=True)
    df['cod_po'] = df['cod_po'].astype(int)
    df['cod_campanha'].fillna(0,inplace=True)
    df['cod_campanha'] = df['cod_campanha'].astype(int)
    df['cod_representante'].fillna(0,inplace=True)
    df['cod_representante'] = df['cod_representante'].astype(int)
    df['cod_veiculo'].fillna(0,inplace=True)
    df['cod_veiculo'] = df['cod_veiculo'].astype(int)
    df['num_contrato'].fillna(0,inplace=True)
    df['num_contrato'] = df['num_contrato'].astype(int)
    df['qtd_faces'].fillna(0,inplace=True)
    df['qtd_faces'] = df['qtd_faces'].astype(int)
    df['qtd_duracao_comercial'].fillna(0,inplace=True)
    df['qtd_duracao_comercial'] = df['qtd_duracao_comercial'].astype(int)
    df['qtd_impressoes'].fillna(0,inplace=True)
    df['qtd_impressoes'] = df['qtd_impressoes'].astype(int)
    df['num_pessoas_impactadas'].fillna(0,inplace=True)
    df['num_pessoas_impactadas'] = df['num_pessoas_impactadas'].astype(int)
    df['qtd_universo_target'].fillna(0,inplace=True)
    df['qtd_universo_target'] = df['qtd_universo_target'].astype(int)
    df['qtd_impressions_target_grp'].fillna(0,inplace=True)
    df['qtd_impressions_target_grp'] = df['qtd_impressions_target_grp'].astype(int)
    df['qtd_impressoes_target_grp_30'].fillna(0,inplace=True)
    df['qtd_impressoes_target_grp_30'] = df['qtd_impressoes_target_grp_30'].astype(int)
    df['qtd_universo_target_secundario'].fillna(0,inplace=True)
    df['qtd_universo_target_secundario'] = df['qtd_universo_target_secundario'].astype(int)
    df['qtd_impressoes_target_grp_secundario '].fillna(0,inplace=True)
    df['qtd_impressoes_target_grp_secundario '] = df['qtd_impressoes_target_grp_secundario '].astype(int)
    df['qtd_impressoes_target_grp_30_secundario'].fillna(0,inplace=True)
    df['qtd_impressoes_target_grp_30_secundario'] = df['qtd_impressoes_target_grp_30_secundario'].astype(int)
    df['qtd_universo'].fillna(0,inplace=True)
    df['qtd_universo'] = df['qtd_universo'].astype(int)
    df['qtd_impressoes_broad_grp  '].fillna(0,inplace=True)
    df['qtd_impressoes_broad_grp  '] = df['qtd_impressoes_broad_grp '].astype(int)
    df['qtd_impressoes_broad_grp_30 '].fillna(0,inplace=True)
    df['qtd_impressoes_broad_grp_30 '] = df['qtd_impressoes_broad_grp_30 '].astype(int)
    df['qtd_exemplares_impressos '].fillna(0,inplace=True)
    df['qtd_exemplares_impressos '] = df['qtd_exemplares_impressos '].astype(int)
    df['num_nota_credito_almap '].fillna(0,inplace=True)
    df['num_nota_credito_almap '] = df['num_nota_credito_almap '].astype(int)
    


    df['val_tabela'].fillna(0,inplace=True)
    df['val_tabela'] = df['val_tabela'].astype(float)
    df['per_desconto'].fillna(0,inplace=True)
    df['per_desconto'] = df['per_desconto'].astype(float)    
    df['val_bruto'].fillna(0,inplace=True)
    df['val_bruto'] = df['val_bruto'].astype(float)    
    df['val_liquido'].fillna(0,inplace=True)
    df['val_liquido'] = df['val_liquido'].astype(float)
    df['val_indice_conversao'].fillna(0,inplace=True)
    df['val_indice_conversao'] = df['val_indice_conversao'].astype(float)    
    df['val_indice_audiencia_target_primario'].fillna(0,inplace=True)
    df['val_indice_audiencia_target_primario'] = df['val_indice_audiencia_target_primario'].astype(float)    
    df['val_indice_audiencia_target_primario_30'].fillna(0,inplace=True)
    df['val_indice_audiencia_target_primario_30'] = df['val_indice_audiencia_target_primario_30'].astype(float)
    df['val_indice_audiencia_target_secundario'].fillna(0,inplace=True)
    df['val_indice_audiencia_target_secundario'] = df['val_indice_audiencia_target_secundario'].astype(float)
    df['val_indice_audiencia_target_secundario_30'].fillna(0,inplace=True)
    df['val_indice_audiencia_target_secundario_30'] = df['val_indice_audiencia_target_secundario_30'].astype(float)    
    df['val_indice_audiencia_grp '].fillna(0,inplace=True)
    df['val_indice_audiencia_grp '] = df['val_indice_audiencia_grp '].astype(float)    
    df['val_indice_audiencia_grp_30 '].fillna(0,inplace=True)
    df['val_indice_audiencia_grp_30 '] = df['val_indice_audiencia_grp_30 '].astype(float)
    df['val_liquido_credito '].fillna(0,inplace=True)
    df['val_liquido_credito '] = df['val_liquido_credito '].astype(float)    
    


    # Converte os campos texto em UPPER
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = df[col].str.upper()    


    return df
